# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
files = ["April_Section_1_Trajectories.csv", "April_Section_2_Trajectories.csv", "April_Section_3_Trajectories.csv", "April_Section_4_Trajectories.csv"]
dfs = [pd.read_csv(f) for f in files]
merged = pd.concat(dfs, ignore_index=True)

# %%
merged.to_csv("4_track.csv", index=False)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("4_track.csv")
